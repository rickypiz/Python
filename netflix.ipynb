# %%
import pandas as pd

# %%
df = pd.read_csv("netflix_titles.csv",sep=",")
df
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 1         s2  TV Show                                      Blood & Water
# 2         s3  TV Show                                          Ganglands
# 3         s4  TV Show                              Jailbirds New Orleans
# 4         s5  TV Show                                       Kota Factory
# 5         s6  TV Show                                      Midnight Mass
# 6         s7    Movie                   My Little Pony: A New Generation
# 7         s8    Movie                                            Sankofa
# 8         s9  TV Show                      The Great British Baking Show
# 9        s10    Movie                                       The Starling
# 10       s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11       s12  TV Show                                   Bangkok Breaking
# ...

# %% [markdown]
# ## 3) how many TV Show and Movie are in dataset?

# %%
df.dropna(inplace=True)
df_show=df[df["type"]=="TV Show"]
df_movie=df[df["type"]=="Movie"]

# %%
df_show.type.value_counts()
# Out:
# TV Show    147
# Name: type, dtype: int64

# %%
df_movie.type.value_counts()
# Out:
# Movie    5185
# Name: type, dtype: int64

# %% [markdown]
# ## 4) Show all the Movies released in year 2000?

# %%
df_movie.loc[df_movie["release_year"]==2000,"title"].count()
# Out:
# 32

# %%
df_show.loc[df_show["release_year"]==2000,"title"].count()
# Out:
# 0

# %%
df_movie[(df_movie["release_year"]==2000)&(df_movie["country"]=="India")][["title","release_year"]]
# Out:
#                             title  release_year
# 4723                         Fiza          2000
# 4956  Phir Bhi Dil Hai Hindustani          2000
# 6440               Chal Mere Bhai          2000
# 6912    Hamara Dil Aapke Paas Hai          2000
# 7247                    Kya Kehna          2000
# 7702               Papa the Great          2000
# 7801                        Pukar          2000

# %% [markdown]
# ## 5) Show only titles of all TV shows were released in India only

# %%
df_show[df_show["country"]=="India"][["title"]]
# Out:
#                                       title
# 297                                Navarasa
# 1293                          Pitta Kathalu
# 1520                        Paava Kadhaigal
# 3036           Jamtara - Sabka Number Ayega
# 4685                                  GHOUL
# 6024                              7 (Seven)
# 8172  Th Eena Meena Deeka Chase Comedy Show

# %% [markdown]
# ## 6) Show Top 10 director who gave highest number of TV shows and movies

# %%
df_movie.director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Jay Karas                 14
# Marcus Raboy              14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Name: director, dtype: int64

# %%
df_show.director.value_counts().head(10)
# Out:
# Alastair Fothergill    3
# Rob Seidenglanz        2
# Shin Won-ho            2
# Stan Lathan            2
# Iginio Straffi         2
# Juan Carlos Medina     1
# Juliana Vicente        1
# Lee Eung-bok           1
# Jay Chandrasekhar      1
# Sion Sono              1
# Name: director, dtype: int64

# %% [markdown]
# ## 7) Show records where type is Movie and Listed_in is comedies" or "Country is United Kingdom"

# %%
df_movie[(df_movie["listed_in"]=="Comedies") | (df_movie["country"]=="United Kingdom")][["type","listed_in","title"]]
# Out:
#        type                                          listed_in  \
# 27    Movie                                           Comedies
# 152   Movie                                           Comedies
# 182   Movie                                           Comedies
# 292   Movie               Comedies, Dramas, Independent Movies
# 304   Movie                                      Documentaries
# 342   Movie                                           Comedies
# 348   Movie                                           Comedies
# 402   Movie                            Dramas, Romantic Movies
# 562   Movie                                           Comedies
# 584   Movie                                           Comedies
# 589   Movie                       Dramas, International Movies
# 821   Movie                 Dramas, Romantic Movies, Thrillers
# 891   Movie  Independent Movies, International Movies, Thri...
# 931   Movie                                           Comedies
# ...

# %% [markdown]
# ## 8) In how many movies/shows, Tom Cruise was cast?

# %%
df_movie.cast.value_counts()
# Out:
# Samuel West                                                                                                                                                                                10
# Jeff Dunham                                                                                                                                                                                 7
# Kevin Hart                                                                                                                                                                                  6
# Jim Gaffigan                                                                                                                                                                                5
# Bill Burr                                                                                                                                                                                   5
# ...

# %%
df_show.loc[df_show["cast"]=="Samuel West", "title"].value_counts().sum()
# Out:
# 0

# %%
df_movie.loc[df_movie["cast"]=="Christian De Sica", "title"].value_counts().sum()
# Out:
# 0

# %% [markdown]
# ## 9) Different ratings

# %%
df_movie[df_movie["cast"].str.contains("Tom Cruise")].count().sum()
# Out:
# 24

# %% [markdown]
# ## 9.1) TV-14 rating in Canada

# %%
df["rating"].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7', 'TV-G',
#        'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## 9.2) TV shows "R"-rating after 2018

# %%
df_movie[(df_movie["rating"]=="TV-14")&(df_movie["country"]=="Canada")][["title"]].count().sum()
# Out:
# 10

# %%
df_show[(df_show["rating"]=="TV-MA")&(df_show["release_year"]>2018)][["title"]].count().sum()
# Out:
# 50

# %% [markdown]
# ## 10) Maximum duration of a Movie/Show on Netflix

# %%
df_movie.sort_values(by="duration",ascending=True).head(1)
# Out:
#      show_id   type              title           director  \
# 6872   s6873  Movie  Gone are the Days  Mark Landre Gould
#
#                                                    cast        country  \
# 6872  Lance Henriksen, Tom Berenger, Meg Steedle, Da...  United States
#
#            date_added  release_year rating duration           listed_in  \
# 6872  January 1, 2019          2018      R  100 min  Independent Movies
#
#                                             description
# 6872  As a notorious outlaw comes to grips with his ...

# %%
#Splitto in due colonna la colonna duration 
df_movie[["Minute","Unit"]]= df_movie["duration"].str.split(' ', expand= True)
# Out:
# /home/student/anaconda3/envs/numpy112/lib/python3.6/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
#la colonna minute contiene stringhe da convertire in numeri interi 
df_movie.Minute.astype(int).max()
# Out:
# 253

# %%
df_show[["Number","Season"]]= df_show["duration"].str.split(' ',expand=True)

# %%
df_show.Number.astype(int).max()
# Out:
# 15

# %% [markdown]
# ## 11) Which individual country has highest number of TV shows?

# %%
df_show.country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Taiwan                                                            7
# Spain                                                             7
# India                                                             7
# Thailand                                                          5
# France                                                            5
# Turkey                                                            5
# Nigeria                                                           4
# Brazil                                                            4
# Canada                                                            3
# Denmark                                                           2
# ...

# %% [markdown]
# ## 12) Sort the dataset by year

# %%
df_year= df.sort_values(by="release_year",ascending=True)

# %%
df_year
# Out:
#      show_id     type                                       title  \
# 8205   s8206    Movie                        The Battle of Midway
# 8640   s8641    Movie                            Tunisian Victory
# 7219   s7220    Movie                     Know Your Enemy - Japan
# 7294   s7295    Movie                          Let There Be Light
# 8587   s8588    Movie                                 Thunderbolt
# 1699   s1700    Movie                             White Christmas
# 2375   s2376    Movie                             The Blazing Sun
# 8506   s8507    Movie                           The Sign of Venus
# 7954   s7955    Movie                         Scandal in Sorrento
# 7839   s7840    Movie                       Rebel Without a Cause
# 2369   s2370    Movie                                 Dark Waters
# 6784   s6785    Movie                            Forbidden Planet
# 6853   s6854    Movie                                        Gigi
# ...

# %% [markdown]
# ## 13) Find all instancies where type is Movie, listed_in is Dramas or Type is TV Show and listed in is Kids TV

# %%
df_movie[df_movie["listed_in"].str.contains("Dramas","Kids'TV")].count()
# Out:
# show_id         2293
# type            2293
# title           2293
# director        2293
# cast            2293
# country         2293
# date_added      2293
# release_year    2293
# rating          2293
# duration        2293
# listed_in       2293
# description     2293
# Minute          2293
# Unit            2293
# dtype: int64

# %%
df_show[df_show["listed_in"].str.contains("Dramas","Kids'TV")].count()
# Out:
# show_id         52
# type            52
# title           52
# director        52
# cast            52
# country         52
# date_added      52
# release_year    52
# rating          52
# duration        52
# listed_in       52
# description     52
# Number          52
# Season          52
# dtype: int64
